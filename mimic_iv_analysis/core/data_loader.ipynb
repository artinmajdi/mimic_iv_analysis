# %%
# %load_ext autoreload
# %autoreload 2

from mimic_iv_analysis.core import DataLoader
import pandas as pd
import dask as dd

# %%
MIMIC_DATA_PATH = "/Users/artinmajdi/Documents/GitHubs/Career/mimic_iv/dataset/mimic-iv-3.1"

data_loader = DataLoader()

# Scan the directory
dataset_info_df, _ = data_loader.scan_mimic_directory()
dataset_info_df
# Out:
# 2025-05-12 18:40:24,680 - INFO - Initializing Filtering class...
#    module          table_name                      file_path  file_size_mb  \
# 0    hosp            provider          hosp/provider.parquet      0.000092
# 1    hosp            patients          hosp/patients.parquet      0.000092
# 2    hosp          poe_detail        hosp/poe_detail.parquet      0.000244
# 3    hosp            services          hosp/services.parquet      0.000092
# 4    hosp           transfers         hosp/transfers.parquet      0.000153
# 5    hosp           labevents          hosp/labevents.csv.gz   2472.790846
# 6    hosp          d_labitems        hosp/d_labitems.parquet      0.000092
# 7    hosp         emar_detail       hosp/emar_detail.parquet      0.000061
# 8    hosp         hcpcsevents       hosp/hcpcsevents.parquet      0.000092
# 9    hosp    d_icd_procedures  hosp/d_icd_procedures.parquet      0.000092
# 10   hosp            pharmacy          hosp/pharmacy.parquet      0.001953
# ...

# %%
from dask.distributed import Client
client = Client(n_workers=2, threads_per_worker=4, processes=True, memory_limit='8GB')
client
# Out:
# 2025-05-12 18:40:33,425 - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2025-05-12 18:40:33,436 - INFO - State start
# 2025-05-12 18:40:33,437 - INFO - Found stale lock file and directory '/var/folders/yr/5jld3pmj3p75vsk6f7dsr6gm0000gn/T/dask-scratch-space/scheduler-fqti8uhg', purging
# 2025-05-12 18:40:33,438 - INFO - Found stale lock file and directory '/var/folders/yr/5jld3pmj3p75vsk6f7dsr6gm0000gn/T/dask-scratch-space/scheduler-8tndp242', purging
# 2025-05-12 18:40:33,438 - INFO - Found stale lock file and directory '/var/folders/yr/5jld3pmj3p75vsk6f7dsr6gm0000gn/T/dask-scratch-space/scheduler-n2rpd3t8', purging
# 2025-05-12 18:40:33,440 - INFO -   Scheduler at:     tcp://127.0.0.1:60362
# 2025-05-12 18:40:33,441 - INFO -   dashboard at:  http://127.0.0.1:8787/status
# 2025-05-12 18:40:33,441 - INFO - Registering Worker plugin shuffle
# ...

# %%
# Out:
# 2025-05-12 18:41:24,421 - INFO - Loading subject IDs from patients table (this will be cached)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data_loader.subject_ids_list
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/functools.py:998, in cached_property.__get__(self, instance, owner)
#     996 val = cache.get(self.attrname, _NOT_FOUND)
#     997 if val is _NOT_FOUND:
# --> 998     val = self.func(instance)
#     999     try:
#    1000         cache[self.attrname] = val
#
# File ~/Documents/GitHubs/Career/mimic_iv/mimic_iv_code/mimic_iv_analysis/core/data_loader.py:376, in subject_ids_list(self)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ...

# %%
import dask.dataframe as dd
from pathlib import Path
from typing import Dict, List
import pandas as pd
import os


def load_csv_with_correct_types(dataset_path: Path, file_path: str, dtypes_all: Dict[str, str], parse_dates_all: List[str]):


    file_path = dataset_path / file_path

    # Check if file exists
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"CSV file not found: {file_path}")

    # First read a small sample to get column names without type conversion
    sample_df = pd.read_csv(file_path, nrows=5)
    columns = sample_df.columns.tolist()

    # Filter dtypes and parse_dates to only include existing columns
    dtypes      = {col: dtype for col, dtype in dtypes_all.items() if col in columns}
    parse_dates = [col for col in parse_dates_all if col in columns]

    # Now read with dask using correct types
    df = dd.read_csv(
        urlpath        = file_path,
        dtype          = dtypes,
        parse_dates    = parse_dates if parse_dates else None,
        assume_missing = True,
        blocksize      = None if file_path.suffix == '.gz' else '200MB'
    )

    return df

from tqdm import tqdm

for i in tqdm( set(range(22,30))  , desc="Loading tables"):

    row = dataset_info_df.iloc[i]
    table_name = row.table_name
    module     = row.module
    file_path = row.file_path
    print(file_path)

    dtypes_all = {
        'discontinued_by_poe_id': 'object',
        'long_description'      : 'string',
        'deathtime'             : 'object',
        'icd_code'              : 'string',
        'drg_type'              : 'category',
        'enter_provider_id'     : 'string',
        'hadm_id'               : 'string',
        'icustay_id'            : 'string',
        'leave_provider_id'     : 'string',
        'poe_id'                : 'string',
        'emar_id'               : 'string',
        'subject_id'            : 'string',
        'pharmacy_id'           : 'string',
        'interpretation'        : 'object',
        'org_name'              : 'object',
        'quantity'              : 'object',
        'infusion_type'         : 'object',
        'sliding_scale'         : 'object',
        'fill_quantity'         : 'object',
        'expiration_unit'       : 'category',
        'duration_interval'     : 'category',
        'dispensation'          : 'category',
        'expirationdate'        : 'object',
        'one_hr_max'            : 'object',
        'infusion_type'         : 'object',
        'sliding_scale'         : 'object',
        'lockout_interval'      : 'object',
        'basal_rate'            : 'object',
        'form_unit_disp'        : 'category',
        'route'                 : 'category',
        'dose_unit_rx'          : 'category',
        'drug_type'             : 'category',
        'form_rx'               : 'object',
        'form_val_disp'         : 'object',
        'gsn'                   : 'object',
        'dose_val_rx'           : 'object',
        'prev_service'          : 'object',
        'curr_service'          : 'category'
    }

    parse_dates_all = ['deathtime', 'admittime', 'dischtime', 'deathtime', 'edregtime', 'edouttime', 'charttime', 'scheduletime','storetime','storedate']

    dataset_path = Path("/Users/artinmajdi/Documents/GitHubs/Career/mimic_iv/dataset/mimic-iv-3.1")

    df = load_csv_with_correct_types(dataset_path=dataset_path, file_path=file_path, dtypes_all=dtypes_all, parse_dates_all=parse_dates_all)

    df.to_parquet(dataset_path / f'{module}/{table_name}.parquet', engine='pyarrow')
# print(df.dtypes)
# df.head(10)

# %%
dfparquet = dd.read_parquet(dataset_path / module / f'{table_name}.parquet')


dfparquet = dfparquet.head(10)

print(dfparquet.dtypes)
dfparquet

# %%
dfparquet.drg_type.cat.categories

# df.drg_code.cat.categories

# %%
# Load table
table_name = 'poe'
module     = 'hosp'

find_row  = dataset_info_df[(dataset_info_df['module'] == module) & (dataset_info_df['table_name'] == table_name)]
file_path = dataset_info_df.attrs['mimic_path'] + '/' + find_row['file_path'].values[0]

print('file_path', file_path)

patients_df, _ = data_loader.load_mimic_table(file_path=file_path, use_dask=False, sample_size=100)
patients_df

# %%
# get total unique subject_ids
subject_ids = data_loader.load_mimic_table(file_path=file_path, use_dask=True, sample_size=100)[0]['subject_id'].unique()
print(len(subject_ids))
